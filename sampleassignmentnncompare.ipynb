# %% [markdown]
# <a href="https://colab.research.google.com/github/smatsuda6/mlprojects/blob/main/sampleassignmentnncompare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4: Benchmarking Neural Nets with the XOR Problem

# %% [markdown]
# ### CS 4774 Machine Learning - Department of Computer Science - University of Virginia
# In this assignment, you will implement your own neural networks to classify non-linear data from the XOR dataset. For references, you may refer to my [lecture 10](https://docs.google.com/presentation/d/1otQfmMomWctLZKI3hHKAA4lLkbXFtagLaQov8gNh4LI/edit?usp=sharing) and [Colab Notebook 10](https://colab.research.google.com/drive/1x5biI3dP5YvvDEI0wapJcSgQNnATDzNe) if you need additional sample codes to help with your assignment. For deliverables, you must write code in Python/Tensorflow and submit **this** Jupyter Notebook file (.ipynb) to earn a total of 100 pts. Note that you must save your Notebook filename under this format: **yourUvaUserId_assignment_4_ann.ipynb**.

# %%
# You might want to use the following packages
import numpy as np
import os
# %tensorflow_version 2.x
import tensorflow as tf

from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from functools import partial

# %% [markdown]
# ---
# ## 1. THE DATASET AND VISUALIZATION
#
# We will use the non-linear toy data called the XOR dataset. You may use the code snippet below to generate the train/validate/test set. Feel free to change the number of samples, and noise level. To keep the ratio between the sets consistent, please do not change the test_size and random_state parameters.

# %%
def make_xor(n_points):
    centers = np.array([[0,0],[0,1],[1,0],[1,1]])
    labels = np.array([0,1,1,0])
    data = np.array([]).reshape(-1,3)
    for center, label in zip(centers,labels):
        points = np.random.normal(loc=center,scale=0.2,size=(n_points//4,2))
        points_labels = np.hstack((points,label*np.ones(n_points//4).reshape((-1, 1))))
        data = np.vstack((data,points_labels))
    return (data[:,[0,1]],data[:,2])


X, y = make_xor(1000)
y=y.astype(np.int64)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=49)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size= 0.1, random_state=49) 
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)
# Out:
# (720, 2)
# (200, 2)
# (80, 2)

# %% [markdown]
# ---
# ## 2. TRAIN A SIMPLE ANN FOR CLASSIFICATION TASK (20 pts)
#
# Use the standard libarary of Neural Net on the training data, and then test the classifier on the test data. You will create a simple ANN with 3 layers: an Input Layer, a Hidden Layer and an Output Layer. For each layer, you can specify the number of nodes appropriate for the XOR problem. Also, feel free to tune the network as you see fit. You have to report the accuracy of the network on the validation set.

# %%
from tensorflow import keras

# Your code here
model = keras.models.Sequential([
    #keras.layers.Dense(2,activation="linear",),
    keras.layers.Dense(4,activation="tanh",input_shape=(2,)),
    keras.layers.Dense(2, activation="softmax")
])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

history = model.fit(X_train_full, y_train_full, epochs=100, validation_data=(X_val, y_val))

model.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.6972 - accuracy: 0.3750 - val_loss: 0.6850 - val_accuracy: 0.3875
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6962 - accuracy: 0.3862 - val_loss: 0.6855 - val_accuracy: 0.4125
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6954 - accuracy: 0.4050 - val_loss: 0.6858 - val_accuracy: 0.4125
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6946 - accuracy: 0.4175 - val_loss: 0.6860 - val_accuracy: 0.4375
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6940 - accuracy: 0.4162 - val_loss: 0.6862 - val_accuracy: 0.4375
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.4387 - val_loss: 0.6862 - val_accuracy: 0.4750
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.4437 - val_loss: 0.6861 - val_accuracy: 0.4875
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.4575 - val_loss: 0.6859 - val_accuracy: 0.4875
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.4588 - val_loss: 0.6858 - val_accuracy: 0.4875
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.4525 - val_loss: 0.6857 - val_accuracy: 0.5000
# Epoch 11/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.4650 - val_loss: 0.6855 - val_accuracy: 0.5000
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.4688 - val_loss: 0.6852 - val_accuracy: 0.5000
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.4737 - val_loss: 0.6849 - val_accuracy: 0.4875
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.4737 - val_loss: 0.6846 - val_accuracy: 0.5000
# Epoch 15/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6889 - accuracy: 0.4775 - val_loss: 0.6842 - val_accuracy: 0.5000
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6885 - accuracy: 0.4825 - val_loss: 0.6838 - val_accuracy: 0.5125
# Epoch 17/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6881 - accuracy: 0.4950 - val_loss: 0.6833 - val_accuracy: 0.5125
# Epoch 18/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6876 - accuracy: 0.4875 - val_loss: 0.6828 - val_accuracy: 0.5000
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6871 - accuracy: 0.4875 - val_loss: 0.6823 - val_accuracy: 0.5125
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.4888 - val_loss: 0.6818 - val_accuracy: 0.5125
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.4850 - val_loss: 0.6813 - val_accuracy: 0.5125
# Epoch 22/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6856 - accuracy: 0.4900 - val_loss: 0.6807 - val_accuracy: 0.5125
# Epoch 23/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.4850 - val_loss: 0.6803 - val_accuracy: 0.5125
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.4875 - val_loss: 0.6798 - val_accuracy: 0.5125
# Epoch 25/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6841 - accuracy: 0.4938 - val_loss: 0.6791 - val_accuracy: 0.5125
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.4913 - val_loss: 0.6785 - val_accuracy: 0.5125
# Epoch 27/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.4938 - val_loss: 0.6778 - val_accuracy: 0.5125
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6824 - accuracy: 0.5000 - val_loss: 0.6772 - val_accuracy: 0.5125
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6818 - accuracy: 0.4963 - val_loss: 0.6765 - val_accuracy: 0.5250
# Epoch 30/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.5175 - val_loss: 0.6760 - val_accuracy: 0.5375
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6807 - accuracy: 0.5238 - val_loss: 0.6754 - val_accuracy: 0.5375
# Epoch 32/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.5038 - val_loss: 0.6746 - val_accuracy: 0.5500
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.5375 - val_loss: 0.6740 - val_accuracy: 0.5625
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6786 - accuracy: 0.5300 - val_loss: 0.6731 - val_accuracy: 0.5750
# Epoch 35/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6778 - accuracy: 0.5387 - val_loss: 0.6724 - val_accuracy: 0.5750
# Epoch 36/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6771 - accuracy: 0.5550 - val_loss: 0.6716 - val_accuracy: 0.6000
# Epoch 37/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6763 - accuracy: 0.5638 - val_loss: 0.6707 - val_accuracy: 0.6000
# Epoch 38/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6756 - accuracy: 0.5675 - val_loss: 0.6699 - val_accuracy: 0.6125
# Epoch 39/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6747 - accuracy: 0.5825 - val_loss: 0.6689 - val_accuracy: 0.6375
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6738 - accuracy: 0.6162 - val_loss: 0.6681 - val_accuracy: 0.6375
# Epoch 41/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6729 - accuracy: 0.6050 - val_loss: 0.6670 - val_accuracy: 0.6625
# Epoch 42/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6720 - accuracy: 0.6475 - val_loss: 0.6662 - val_accuracy: 0.6750
# Epoch 43/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6711 - accuracy: 0.6475 - val_loss: 0.6652 - val_accuracy: 0.6875
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6701 - accuracy: 0.6550 - val_loss: 0.6642 - val_accuracy: 0.7000
# Epoch 45/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.6525 - val_loss: 0.6630 - val_accuracy: 0.7375
# Epoch 46/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6682 - accuracy: 0.6650 - val_loss: 0.6619 - val_accuracy: 0.7375
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6671 - accuracy: 0.6700 - val_loss: 0.6608 - val_accuracy: 0.7375
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6737 - val_loss: 0.6595 - val_accuracy: 0.7375
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6648 - accuracy: 0.6762 - val_loss: 0.6583 - val_accuracy: 0.7375
# Epoch 50/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6636 - accuracy: 0.6850 - val_loss: 0.6570 - val_accuracy: 0.7375
# Epoch 51/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0.6975 - val_loss: 0.6558 - val_accuracy: 0.7375
# Epoch 52/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6612 - accuracy: 0.6963 - val_loss: 0.6545 - val_accuracy: 0.7500
# Epoch 53/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.6950 - val_loss: 0.6530 - val_accuracy: 0.7625
# Epoch 54/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6585 - accuracy: 0.7000 - val_loss: 0.6515 - val_accuracy: 0.7875
# Epoch 55/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6572 - accuracy: 0.7075 - val_loss: 0.6502 - val_accuracy: 0.7875
# Epoch 56/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6558 - accuracy: 0.7063 - val_loss: 0.6487 - val_accuracy: 0.7875
# Epoch 57/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6544 - accuracy: 0.7113 - val_loss: 0.6472 - val_accuracy: 0.7875
# Epoch 58/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6528 - accuracy: 0.7163 - val_loss: 0.6456 - val_accuracy: 0.7875
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6513 - accuracy: 0.7200 - val_loss: 0.6440 - val_accuracy: 0.8000
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6497 - accuracy: 0.7212 - val_loss: 0.6424 - val_accuracy: 0.8000
# Epoch 61/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6481 - accuracy: 0.7275 - val_loss: 0.6406 - val_accuracy: 0.8000
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6464 - accuracy: 0.7275 - val_loss: 0.6390 - val_accuracy: 0.8000
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6447 - accuracy: 0.7237 - val_loss: 0.6373 - val_accuracy: 0.8000
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6430 - accuracy: 0.7375 - val_loss: 0.6354 - val_accuracy: 0.8000
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6411 - accuracy: 0.7513 - val_loss: 0.6334 - val_accuracy: 0.8000
# Epoch 66/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6394 - accuracy: 0.7450 - val_loss: 0.6314 - val_accuracy: 0.8000
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6375 - accuracy: 0.7525 - val_loss: 0.6294 - val_accuracy: 0.8000
# Epoch 68/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6355 - accuracy: 0.7500 - val_loss: 0.6274 - val_accuracy: 0.8000
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6336 - accuracy: 0.7588 - val_loss: 0.6253 - val_accuracy: 0.8000
# Epoch 70/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6314 - accuracy: 0.7600 - val_loss: 0.6232 - val_accuracy: 0.8000
# Epoch 71/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6293 - accuracy: 0.7700 - val_loss: 0.6210 - val_accuracy: 0.8125
# Epoch 72/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6273 - accuracy: 0.7613 - val_loss: 0.6189 - val_accuracy: 0.8125
# Epoch 73/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6250 - accuracy: 0.7588 - val_loss: 0.6169 - val_accuracy: 0.8125
# Epoch 74/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6227 - accuracy: 0.7887 - val_loss: 0.6144 - val_accuracy: 0.8250
# Epoch 75/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6204 - accuracy: 0.7788 - val_loss: 0.6122 - val_accuracy: 0.8500
# Epoch 76/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6181 - accuracy: 0.7837 - val_loss: 0.6098 - val_accuracy: 0.8500
# Epoch 77/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6157 - accuracy: 0.7975 - val_loss: 0.6073 - val_accuracy: 0.8500
# Epoch 78/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6132 - accuracy: 0.8012 - val_loss: 0.6047 - val_accuracy: 0.8500
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6108 - accuracy: 0.8062 - val_loss: 0.6021 - val_accuracy: 0.8500
# Epoch 80/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6082 - accuracy: 0.8000 - val_loss: 0.5996 - val_accuracy: 0.8625
# Epoch 81/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6056 - accuracy: 0.8112 - val_loss: 0.5969 - val_accuracy: 0.8625
# Epoch 82/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6030 - accuracy: 0.8075 - val_loss: 0.5943 - val_accuracy: 0.8750
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6003 - accuracy: 0.8125 - val_loss: 0.5916 - val_accuracy: 0.8750
# Epoch 84/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5975 - accuracy: 0.8138 - val_loss: 0.5890 - val_accuracy: 0.8875
# Epoch 85/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5947 - accuracy: 0.8313 - val_loss: 0.5862 - val_accuracy: 0.8875
# Epoch 86/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.8388 - val_loss: 0.5832 - val_accuracy: 0.8875
# Epoch 87/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5889 - accuracy: 0.8462 - val_loss: 0.5803 - val_accuracy: 0.8875
# Epoch 88/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5860 - accuracy: 0.8425 - val_loss: 0.5773 - val_accuracy: 0.8875
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5830 - accuracy: 0.8788 - val_loss: 0.5741 - val_accuracy: 0.8875
# Epoch 90/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5800 - accuracy: 0.8725 - val_loss: 0.5709 - val_accuracy: 0.8875
# Epoch 91/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5770 - accuracy: 0.8725 - val_loss: 0.5678 - val_accuracy: 0.9000
# Epoch 92/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5738 - accuracy: 0.8575 - val_loss: 0.5649 - val_accuracy: 0.9125
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5706 - accuracy: 0.8888 - val_loss: 0.5617 - val_accuracy: 0.9125
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5673 - accuracy: 0.8963 - val_loss: 0.5585 - val_accuracy: 0.9375
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5642 - accuracy: 0.9125 - val_loss: 0.5549 - val_accuracy: 0.9375
# Epoch 96/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5609 - accuracy: 0.9212 - val_loss: 0.5513 - val_accuracy: 0.9375
# Epoch 97/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5574 - accuracy: 0.9175 - val_loss: 0.5479 - val_accuracy: 0.9375
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5541 - accuracy: 0.9162 - val_loss: 0.5445 - val_accuracy: 0.9375
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5506 - accuracy: 0.9287 - val_loss: 0.5409 - val_accuracy: 0.9375
# Epoch 100/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5471 - accuracy: 0.9275 - val_loss: 0.5374 - val_accuracy: 0.9375
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5533 - accuracy: 0.9150
# [0.5533189177513123, 0.9150000214576721]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 12
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 10
# =================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - - -
# ## 3. IMPLEMENTING YOUR OWN SIMPLE NEURAL NETWORK (60 pts)
#
# Now that you see how the standard library ANN performs on the XOR dataset, you will attempt to implement your own version of the neural network. To help you, a template has been created including the backpropagation. Essensially, you will get the backward gradients for free. However, please note that the backprop implementation assume usage of tanh activation for the hidden layer and softmax for the output layer. There are some subtasks which you need to implement in order to get the network to work properly.

# %%
from sklearn.base import BaseEstimator
import math

class MyNeuralNet(BaseEstimator):
    """Your implementation of a simple neural network"""

    def __init__ (self, nn_input_dim, nn_hidden_dim, nn_output_dim):
        """
        Initialize the network with random weights

        @param: nn_input_dim: Number of nodes in the input layer
        @param: nn_hidden_dim: Number of nodes in the hidden layer
        @param: nn_output_dim: Number of nodes in the output layer
        """
        # SUBTASK 1 (10 pts): Initialize the parameters to random values.
        np.random.seed(49)
        self.alpha = alpha
        self.W1 = np.random.rand(nn_input_dim,nn_hidden_dim)
        self.b1 = np.random.rand(1,nn_hidden_dim)
        self.W2 = np.random.rand(nn_hidden_dim,nn_output_dim)
        self.b2 = np.random.rand(1,nn_output_dim)
        print(self)
        
    def loss(self, X, y):
        """
        Evaluate the average loss on the dataset
        """
        # Forward propagation will be needed to calculate the loss
        a1,a2 = self.forward_pass(X)
        # SUBTASK 2 (10 pts): Calculate the loss using log-loss probabilities using a2.
        # You will need to return the average loss on the data 


        return *(-1/y.size)*np.sum(np.dot(y,np.log(a2))+np.dot((1-y),np.log(a2)))


    def forward_pass(self, X):
        """
        Pass the signal forward through the layers.
        @param: X: feature
        @return: a1: saved value of the output of the hidden layer
        @return: a2: activated return value of the output layer.
        """
        # SUBTASK 3 (20 pts): Implement Forward propagation.
        # Note that you must implement tanh activiation for the hiden layer, and softmax for the output layer

        z1 = X.dot(self.W1) + self.b1
        a1 = np.tanh(z1)
        z2 = a1.dot(self.W2) + self.b2
        a2 = np.exp(z2)/np.sum(np.exp(z2), axis=1, keepdims=True)


        return a1, a2

    def backward_pass(self,a1,a2,X,y):
        """
        Pass the signal back and compute the gradient

        @param: X: feature
        @param: y: label
        @param: a1: saved value of the output of the hidden layer
        @param: a2: activated return value of the output layer.

        @return: dW1: the gradient of W1
        @return: db1: the gradient of b1
        @return: dW2: the gradient of W2
        @return: db2: the gradient of b2
        """
        # You do not have to change this function, ...
        # unless you are advanced and want to use different activation function.
        m = len(y) # number of example
        delta2 = a2
        y.astype(np.int64)
        delta2[range(m), y] -= 1
        dW2 = (a1.T).dot(delta2)
        db2 = np.sum(delta2, axis=0, keepdims=True)
        delta1 = delta2.dot(self.W2.T) * (1 - np.power(a1, 2))
        dW1 = np.dot(X.T, delta1)
        db1 = np.sum(delta1, axis=0)
        return dW1, db1, dW2, db2

    def fit(self, X, y, epochs, X_val, y_val):
        """
        Learns parameters for the neural network and returns the model.
        
        @param: X: the training feature
        @param: y: the train label
        @param: epochs: Number of passes through the training data for gradient descent
        @param: X_val: the feature of validation set
        @param: y_val: the label of validation set
        """

        # Gradient descent. For each batch...
        for i in range(0, epochs):

            # Forward pass
            a1,a2 = self.forward_pass(X);

            # Backpropagation
            dW1, db1, dW2, db2 = self.backward_pass(a1,a2,X,y)

            # SUBTASK 4 (10 pts): Compute the gradient descent parameter update
            self.W1 = self.W1 - alpha*dW1
            self.b1 = self.b1 - alpha*db1
            self.W2 = self.W2 - alpha*dW2
            self.b2 = self.b2 - alpha*db2
        
            # Print the loss and validation accuracy at current epoch.
            if i % 10 == 0:
                print("Epoch %i/%i - loss: %f - accuracy: %f - val_loss: %f - val_acc: %f" 
                      %(i,epochs, self.loss(X_train, y_train), self.evaluate(X_train, y_train),
                        self.loss(X_val, y_val), self.evaluate(X_val,y_val)))


    def evaluate(self, X, y):
        """
        Evaluate the accuracy of the model
        """
        y_pred = self.predict(X)
        return sum(y_pred == y)/len(y)

    def predict(self, X):
        """
        Predict an output

        @param: X: feature
        @return: y_pred: predicted label (0 or 1)
        """
        # SUBTASK 5 (10 pts): Implement the prediction process. 
        # Hint: It should include a forward pass, and then use the class with higher probability.

        a1, a2 = self.forward_pass(X)
        y_pred = np.argmax(a2,axis=1)
        return y_pred


    def plot_decision_boundary(self, pred_func):
        """
        Plot a decision boundary for visualization purpose.
        If you don't fully understand this function don't worry, it just generates the contour plot below.
        """
        # Set min and max values and give it some padding
        x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
        y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
        h = 0.01
        # Generate a grid of points with distance h between them
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        # Predict the function value for the whole gid
        Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
        Z = Z.reshape(xx.shape)
        # Plot the contour and training examples
        plt.contourf(xx, yy, Z, cmap=plt.cm.Pastel1)
        plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

# %% [markdown]
# ---
# ## 4. REFLECT ON THE COMPARISON BETWEEN YOUR IMPLEMENTATION TO THE STANDARD LIBRARY (20 pts)
# Now that you have implemented your own Neural Net class, let's use it! Create at least 3 instances of your Neural Net class, each with a different number of nodes in the hiden layer, tune it with the appropriate learning rate and number of iteration. You will test their performance in the Xor dataset and report the test accuracy metrics for each instance of your neural network.
#
# Based on the test accuracy, compare your models with the standard library version.

# %%
# MODEL 1: Some hyperparameters are provided, but feel free to change them.
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 2 # output layer dimensionality
nn_hidden_dim = 4 # hiden layer dimensionality
alpha = 0.01 # learning rate for gradient descent
epochs = 200 # number of iteration/epochs
# Build a model with 3 layer
myModel1 = MyNeuralNet(nn_input_dim, nn_hidden_dim, nn_output_dim);


myModel1.fit(X_train, y_train, epochs, X_val, y_val)

# Plot the decision boundary
#myModel1.plot_decision_boundary(lambda x: myModel1.predict(x))
# See the weights and biases of the network
print(myModel1.W1)
print(myModel1.b1)
print(myModel1.W2)
print(myModel1.b2)


# MODEL 2 here
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 5 # output layer dimensionality
nn_hidden_dim = 4 # hiden layer dimensionality
alpha = 0.01 # learning rate for gradient descent
epochs = 200 # number of iteration/epochs
# Build a model with 3 layer
myModel1 = MyNeuralNet(nn_input_dim, nn_hidden_dim, nn_output_dim);


myModel1.fit(X_train, y_train, epochs, X_val, y_val)

# Plot the decision boundary
#myModel1.plot_decision_boundary(lambda x: myModel1.predict(x))
# See the weights and biases of the network
print(myModel1.W1)
print(myModel1.b1)
print(myModel1.W2)
print(myModel1.b2)

# MODEL 3 here
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 10 # output layer dimensionality
nn_hidden_dim = 4 # hiden layer dimensionality
alpha = 0.01 # learning rate for gradient descent
epochs = 200 # number of iteration/epochs
# Build a model with 3 layer
myModel1 = MyNeuralNet(nn_input_dim, nn_hidden_dim, nn_output_dim);


myModel1.fit(X_train, y_train, epochs, X_val, y_val)

# Plot the decision boundary
#myModel1.plot_decision_boundary(lambda x: myModel1.predict(x))
# See the weights and biases of the network
print(myModel1.W1)
print(myModel1.b1)
print(myModel1.W2)
print(myModel1.b2)

# COMPARISONS WITH THE STANDARD LIBRARY 

model = keras.models.Sequential([
    keras.layers.Dense(4,activation="tanh",input_shape=(2,)),
    keras.layers.Dense(2, activation="softmax")
])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

history = model.fit(X_train_full, y_train_full, epochs=50, validation_data=(X_val, y_val))

model.evaluate(X_test, y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# MyNeuralNet(nn_hidden_dim=None, nn_input_dim=None, nn_output_dim=None)
# Epoch 0/200 - loss: 10.158151 - accuracy: 0.486111 - val_loss: 10.308956 - val_acc: 0.587500
# Epoch 10/200 - loss: 17.610892 - accuracy: 0.513889 - val_loss: 17.859194 - val_acc: 0.412500
# Epoch 20/200 - loss: 5.245394 - accuracy: 0.513889 - val_loss: 4.830702 - val_acc: 0.412500
# Epoch 30/200 - loss: 7.872697 - accuracy: 0.630556 - val_loss: 6.943610 - val_acc: 0.675000
# Epoch 40/200 - loss: 15.299423 - accuracy: 0.513889 - val_loss: 14.652614 - val_acc: 0.412500
# Epoch 50/200 - loss: 19.373539 - accuracy: 0.698611 - val_loss: 20.363134 - val_acc: 0.750000
# Epoch 60/200 - loss: 14.216900 - accuracy: 0.513889 - val_loss: 14.490552 - val_acc: 0.412500
# Epoch 70/200 - loss: 15.831132 - accuracy: 0.712500 - val_loss: 16.302425 - val_acc: 0.750000
# Epoch 80/200 - loss: 12.842843 - accuracy: 0.701389 - val_loss: 13.528078 - val_acc: 0.750000
# Epoch 90/200 - loss: 5.489942 - accuracy: 0.947222 - val_loss: 5.193462 - val_acc: 0.950000
# Epoch 100/200 - loss: 5.083939 - accuracy: 0.941667 - val_loss: 5.032139 - val_acc: 0.925000
# Epoch 110/200 - loss: 4.587090 - accuracy: 0.943056 - val_loss: 4.614488 - val_acc: 0.925000
# Epoch 120/200 - loss: 4.345949 - accuracy: 0.941667 - val_loss: 4.461892 - val_acc: 0.925000
# Epoch 130/200 - loss: 4.227516 - accuracy: 0.941667 - val_loss: 4.362394 - val_acc: 0.937500
# Epoch 140/200 - loss: 4.173528 - accuracy: 0.940278 - val_loss: 4.315166 - val_acc: 0.937500
# Epoch 150/200 - loss: 4.145540 - accuracy: 0.941667 - val_loss: 4.291219 - val_acc: 0.937500
# Epoch 160/200 - loss: 4.118763 - accuracy: 0.940278 - val_loss: 4.262066 - val_acc: 0.937500
# Epoch 170/200 - loss: 4.105521 - accuracy: 0.943056 - val_loss: 4.246442 - val_acc: 0.937500
# Epoch 180/200 - loss: 4.110835 - accuracy: 0.943056 - val_loss: 4.258254 - val_acc: 0.937500
# Epoch 190/200 - loss: 4.090482 - accuracy: 0.941667 - val_loss: 4.234792 - val_acc: 0.937500
# [[ 6.36293077  3.84880862 13.81456388  9.63991116]
#  [ 6.5105825   1.22000562 14.17039402  9.20559477]]
# [[  9.74233742   6.65227493  -6.32241941 -14.42130385]]
# [[ 0.0431955   1.20144781]
#  [-1.01299133  2.08696084]
#  [-1.32749661  2.34858248]
#  [ 2.28996888 -1.68796685]]
# [[ 5.40179015 -3.99227502]]
# MyNeuralNet(nn_hidden_dim=None, nn_input_dim=None, nn_output_dim=None)
# Epoch 0/200 - loss: 36.445132 - accuracy: 0.513889 - val_loss: 37.103288 - val_acc: 0.412500
# Epoch 10/200 - loss: 66.891594 - accuracy: 0.513889 - val_loss: 66.939580 - val_acc: 0.412500
# Epoch 20/200 - loss: 70.353893 - accuracy: 0.513889 - val_loss: 71.297873 - val_acc: 0.412500
# Epoch 30/200 - loss: 82.648902 - accuracy: 0.513889 - val_loss: 82.667786 - val_acc: 0.412500
# Epoch 40/200 - loss: 59.612760 - accuracy: 0.655556 - val_loss: 59.020072 - val_acc: 0.612500
# Epoch 50/200 - loss: 48.507672 - accuracy: 0.684722 - val_loss: 48.758528 - val_acc: 0.737500
# Epoch 60/200 - loss: 50.193748 - accuracy: 0.715278 - val_loss: 51.401631 - val_acc: 0.787500
# Epoch 70/200 - loss: 50.122281 - accuracy: 0.712500 - val_loss: 51.051474 - val_acc: 0.787500
# Epoch 80/200 - loss: 50.565611 - accuracy: 0.706944 - val_loss: 51.051107 - val_acc: 0.787500
# Epoch 90/200 - loss: 50.787431 - accuracy: 0.702778 - val_loss: 50.996962 - val_acc: 0.787500
# Epoch 100/200 - loss: 51.082004 - accuracy: 0.718056 - val_loss: 51.232936 - val_acc: 0.787500
# Epoch 110/200 - loss: 51.294607 - accuracy: 0.718056 - val_loss: 51.450632 - val_acc: 0.787500
# Epoch 120/200 - loss: 51.479954 - accuracy: 0.720833 - val_loss: 51.646833 - val_acc: 0.787500
# Epoch 130/200 - loss: 51.643669 - accuracy: 0.720833 - val_loss: 51.816020 - val_acc: 0.787500
# Epoch 140/200 - loss: 51.786456 - accuracy: 0.722222 - val_loss: 51.960223 - val_acc: 0.787500
# Epoch 150/200 - loss: 51.911125 - accuracy: 0.722222 - val_loss: 52.084499 - val_acc: 0.787500
# Epoch 160/200 - loss: 52.020929 - accuracy: 0.722222 - val_loss: 52.193235 - val_acc: 0.787500
# Epoch 170/200 - loss: 52.118753 - accuracy: 0.723611 - val_loss: 52.289758 - val_acc: 0.787500
# Epoch 180/200 - loss: 52.206934 - accuracy: 0.723611 - val_loss: 52.376544 - val_acc: 0.787500
# Epoch 190/200 - loss: 52.287298 - accuracy: 0.723611 - val_loss: 52.455451 - val_acc: 0.787500
# [[ -2.78774333  -8.01406364  18.59287217  -3.60393129]
#  [ -3.41815065  -6.08710427 -13.82391922  -9.80999033]]
# [[ -5.71373361   2.7693866    5.43212776 -12.29011017]]
# [[-0.47099574 -0.1601872   1.18815582  0.60742204  2.11638544]
#  [ 2.1898871  -3.21397581  0.52312532  0.85762226  1.71377663]
#  [ 5.67460049 -4.53672886  0.2711974   0.32170443  1.50116458]
#  [-0.34933073  2.863208   -0.45005069 -0.37044181  0.09964094]]
# [[ 9.84016543  3.61239543 -1.13816931 -1.14990518 -6.89868408]]
# MyNeuralNet(nn_hidden_dim=None, nn_input_dim=None, nn_output_dim=None)
# Epoch 0/200 - loss: 106.298131 - accuracy: 0.487500 - val_loss: 108.096329 - val_acc: 0.587500
# Epoch 10/200 - loss: 251.651732 - accuracy: 0.513889 - val_loss: 251.647663 - val_acc: 0.412500
# Epoch 20/200 - loss: 277.692867 - accuracy: 0.513889 - val_loss: 277.683234 - val_acc: 0.412500
# Epoch 30/200 - loss: 275.253089 - accuracy: 0.513889 - val_loss: 275.175117 - val_acc: 0.412500
# Epoch 40/200 - loss: 222.178282 - accuracy: 0.513889 - val_loss: 222.205350 - val_acc: 0.412500
# Epoch 50/200 - loss: 207.597436 - accuracy: 0.513889 - val_loss: 207.497529 - val_acc: 0.412500
# Epoch 60/200 - loss: 233.830510 - accuracy: 0.513889 - val_loss: 233.641879 - val_acc: 0.412500
# Epoch 70/200 - loss: 152.208178 - accuracy: 0.712500 - val_loss: 151.559668 - val_acc: 0.662500
# Epoch 80/200 - loss: 153.687963 - accuracy: 0.486111 - val_loss: 154.336144 - val_acc: 0.587500
# Epoch 90/200 - loss: 221.151437 - accuracy: 0.719444 - val_loss: 220.430917 - val_acc: 0.637500
# Epoch 100/200 - loss: 159.303138 - accuracy: 0.730556 - val_loss: 160.102672 - val_acc: 0.662500
# Epoch 110/200 - loss: 148.993733 - accuracy: 0.486111 - val_loss: 150.244365 - val_acc: 0.587500
# Epoch 120/200 - loss: 225.226329 - accuracy: 0.719444 - val_loss: 224.303625 - val_acc: 0.637500
# Epoch 130/200 - loss: 162.795010 - accuracy: 0.720833 - val_loss: 163.638370 - val_acc: 0.662500
# Epoch 140/200 - loss: 147.030677 - accuracy: 0.486111 - val_loss: 148.335012 - val_acc: 0.587500
# Epoch 150/200 - loss: 224.739181 - accuracy: 0.725000 - val_loss: 223.640784 - val_acc: 0.637500
# Epoch 160/200 - loss: 163.162996 - accuracy: 0.727778 - val_loss: 164.208891 - val_acc: 0.662500
# Epoch 170/200 - loss: 145.042190 - accuracy: 0.486111 - val_loss: 146.561408 - val_acc: 0.587500
# Epoch 180/200 - loss: 225.084852 - accuracy: 0.725000 - val_loss: 223.842682 - val_acc: 0.637500
# Epoch 190/200 - loss: 164.252482 - accuracy: 0.729167 - val_loss: 165.423939 - val_acc: 0.662500
# [[-18.07267898   1.55344801   1.04860051  -2.19519936]
#  [ 21.20385465   0.10210035  -0.45742577  -4.73386229]]
# [[-11.03207775   8.43812685   5.98006357  -6.95855035]]
# [[-5.08342415  8.55494688  0.68347514 -0.04658628 -0.11134805 -0.12243225
#    0.2696807   0.75683805  0.53916909 -0.08910327]
#  [ 2.96404595  4.6203319  -0.14515318 -0.14944582 -0.65583709 -0.5127769
#   -0.00940928 -0.39933254 -0.16337534 -0.52408397]
#  [ 1.74203559  4.23883355  0.61139904  0.46414955 -0.4866875   0.33619143
#    0.46248745  0.29185817  0.27085957 -0.72518094]
#  [-0.69237015  1.32165496  0.22331161  0.81194528 -0.1232556   0.98416528
#    0.7176376   0.93214671  0.63020722  0.43520608]]
# [[ 5.43509052  5.34182139 -0.80315906 -0.68329815 -1.61574394 -0.61792476
#   -0.6202046  -0.69267372 -0.57105607 -1.26952757]]
# Epoch 1/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.8827 - accuracy: 0.6612 - val_loss: 0.7177 - val_accuracy: 0.7250
# Epoch 2/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.8065 - accuracy: 0.7063 - val_loss: 0.6902 - val_accuracy: 0.7625
# Epoch 3/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.7628 - accuracy: 0.7138 - val_loss: 0.6805 - val_accuracy: 0.7500
# Epoch 4/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.7378 - accuracy: 0.6775 - val_loss: 0.6782 - val_accuracy: 0.7000
# Epoch 5/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.7231 - accuracy: 0.6400 - val_loss: 0.6782 - val_accuracy: 0.6750
# Epoch 6/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.7131 - accuracy: 0.5875 - val_loss: 0.6784 - val_accuracy: 0.6250
# Epoch 7/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.7059 - accuracy: 0.5487 - val_loss: 0.6780 - val_accuracy: 0.6000
# Epoch 8/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.7001 - accuracy: 0.5138 - val_loss: 0.6766 - val_accuracy: 0.5625
# Epoch 9/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6950 - accuracy: 0.5238 - val_loss: 0.6754 - val_accuracy: 0.5375
# Epoch 10/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.5038 - val_loss: 0.6738 - val_accuracy: 0.5250
# Epoch 11/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.4900 - val_loss: 0.6716 - val_accuracy: 0.5000
# Epoch 12/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6825 - accuracy: 0.5075 - val_loss: 0.6697 - val_accuracy: 0.5125
# Epoch 13/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6789 - accuracy: 0.5000 - val_loss: 0.6675 - val_accuracy: 0.5125
# Epoch 14/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6755 - accuracy: 0.4988 - val_loss: 0.6648 - val_accuracy: 0.5250
# Epoch 15/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6723 - accuracy: 0.5138 - val_loss: 0.6625 - val_accuracy: 0.5625
# Epoch 16/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6693 - accuracy: 0.5075 - val_loss: 0.6599 - val_accuracy: 0.5875
# Epoch 17/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6664 - accuracy: 0.5512 - val_loss: 0.6582 - val_accuracy: 0.5750
# Epoch 18/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6637 - accuracy: 0.5225 - val_loss: 0.6555 - val_accuracy: 0.6000
# Epoch 19/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6609 - accuracy: 0.5813 - val_loss: 0.6540 - val_accuracy: 0.6000
# Epoch 20/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.5525 - val_loss: 0.6517 - val_accuracy: 0.6000
# Epoch 21/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6559 - accuracy: 0.5750 - val_loss: 0.6495 - val_accuracy: 0.6250
# Epoch 22/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6534 - accuracy: 0.5875 - val_loss: 0.6474 - val_accuracy: 0.6375
# Epoch 23/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6510 - accuracy: 0.5938 - val_loss: 0.6451 - val_accuracy: 0.6625
# Epoch 24/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6488 - accuracy: 0.6000 - val_loss: 0.6426 - val_accuracy: 0.6750
# Epoch 25/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6465 - accuracy: 0.6288 - val_loss: 0.6407 - val_accuracy: 0.6750
# Epoch 26/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6441 - accuracy: 0.6313 - val_loss: 0.6386 - val_accuracy: 0.7125
# Epoch 27/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6550 - val_loss: 0.6367 - val_accuracy: 0.7125
# Epoch 28/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6395 - accuracy: 0.6675 - val_loss: 0.6349 - val_accuracy: 0.7125
# Epoch 29/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6372 - accuracy: 0.6475 - val_loss: 0.6322 - val_accuracy: 0.7250
# Epoch 30/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6350 - accuracy: 0.6812 - val_loss: 0.6302 - val_accuracy: 0.7375
# Epoch 31/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6327 - accuracy: 0.6900 - val_loss: 0.6276 - val_accuracy: 0.7750
# Epoch 32/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6303 - accuracy: 0.7000 - val_loss: 0.6255 - val_accuracy: 0.7750
# Epoch 33/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6280 - accuracy: 0.7163 - val_loss: 0.6236 - val_accuracy: 0.7750
# Epoch 34/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6257 - accuracy: 0.7312 - val_loss: 0.6213 - val_accuracy: 0.7875
# Epoch 35/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6231 - accuracy: 0.7563 - val_loss: 0.6186 - val_accuracy: 0.8000
# Epoch 36/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6208 - accuracy: 0.7638 - val_loss: 0.6161 - val_accuracy: 0.8000
# Epoch 37/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6182 - accuracy: 0.7663 - val_loss: 0.6141 - val_accuracy: 0.8250
# Epoch 38/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6158 - accuracy: 0.7875 - val_loss: 0.6117 - val_accuracy: 0.8375
# Epoch 39/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6133 - accuracy: 0.8112 - val_loss: 0.6088 - val_accuracy: 0.8625
# Epoch 40/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6106 - accuracy: 0.8363 - val_loss: 0.6057 - val_accuracy: 0.8625
# Epoch 41/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6080 - accuracy: 0.8213 - val_loss: 0.6031 - val_accuracy: 0.8625
# Epoch 42/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6053 - accuracy: 0.8213 - val_loss: 0.6009 - val_accuracy: 0.8625
# Epoch 43/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6025 - accuracy: 0.8575 - val_loss: 0.5981 - val_accuracy: 0.8750
# Epoch 44/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5998 - accuracy: 0.8863 - val_loss: 0.5951 - val_accuracy: 0.8875
# Epoch 45/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.8863 - val_loss: 0.5919 - val_accuracy: 0.9000
# Epoch 46/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5943 - accuracy: 0.8975 - val_loss: 0.5888 - val_accuracy: 0.9000
# Epoch 47/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5912 - accuracy: 0.8900 - val_loss: 0.5859 - val_accuracy: 0.9000
# Epoch 48/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5883 - accuracy: 0.8825 - val_loss: 0.5833 - val_accuracy: 0.9125
# Epoch 49/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5852 - accuracy: 0.8963 - val_loss: 0.5804 - val_accuracy: 0.9125
# Epoch 50/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5821 - accuracy: 0.9212 - val_loss: 0.5771 - val_accuracy: 0.9125
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5895 - accuracy: 0.8950
# [0.5895010828971863, 0.8949999809265137]
